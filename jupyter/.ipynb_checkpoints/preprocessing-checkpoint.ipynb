# %%
# common
import pandas as pd
import numpy as np
from pandas import DataFrame

train_data= pd.read_csv('../csv/train.csv', low_memory=False)
test_data = pd.read_csv('../csv/test.csv')

# %%
train_data.head()
# Out:
#   state   stop_date stop_time location_raw       county_name  county_fips  \
# 0    CT  2014-09-23     18:59       berlin   Hartford County       9003.0
# 1    CT  2014-08-10     16:32    greenwich  Fairfield County       9001.0
# 2    CT  2013-12-17     18:26     brooklyn    Windham County       9015.0
# 3    CT  2014-02-07     17:05        essex  Middlesex County       9007.0
# 4    CT  2014-11-05     04:44        union    Tolland County       9013.0
#
#          fine_grained_location police_department driver_gender  \
# 0                       9n x21      State Police             M
# 1          RT.15 W/B REST-AREA      State Police             M
# 2                         rt 6      State Police             M
# 3   00000 S RT 9 (ESSEX, T050)      State Police             F
# 4  00000 N I 84  (UNION, T145)      State Police             M
#
#    driver_age_raw     ...      driver_race     violation_raw  \
# 0              46     ...            White  Moving Violation
# ...

# %%
train_data.county_fips.value_counts()
# Out:
# 9009.0    34564
# 9011.0    31957
# 9013.0    31770
# 9001.0    29153
# 9003.0    27637
# 9007.0    25716
# 9015.0    19785
# 9005.0    18709
# Name: county_fips, dtype: int64

# %%
train_data.loc[:,['fine_grained_location','county_fips']]
# Out:
#                                     fine_grained_location  county_fips
# 0                                                  9n x21       9003.0
# 1                                     RT.15 W/B REST-AREA       9001.0
# 2                                                    rt 6       9015.0
# 3                              00000 S RT 9 (ESSEX, T050)       9007.0
# 4                             00000 N I 84  (UNION, T145)       9013.0
# 5                                              rt8 sb x13       9001.0
# 6                                                cross st       9009.0
# 7                         00063 W I 84 (MANCHESTER, T077)       9003.0
# 8                                            exit 16 t080       9009.0
# 9                                     RT-25 S/B 2 ON RAMP       9001.0
# 10                                             Rt 9 N 6-7       9007.0
# 11      00000 W GOVERNOR JOHN DAVIS LODGE TNPK (MONTVI...       9011.0
# ...

# %%
train_data.driver_age
# Out:
# 0         46.0
# 1         38.0
# 2         23.0
# 3         23.0
# 4         42.0
# 5         29.0
# 6         22.0
# 7         49.0
# 8         29.0
# 9         37.0
# 10        29.0
# 11        42.0
# 12        33.0
# 13        46.0
# 14        27.0
# 15        70.0
# 16        49.0
# 17        45.0
# 18        30.0
# 19        55.0
# 20        25.0
# 21        74.0
# 22        30.0
# 23        20.0
# 24        43.0
# 25        25.0
# 26        52.0
# 27        36.0
# 28        22.0
# 29        45.0
#           ...
# 219289    24.0
# 219290    22.0
# 219291    57.0
# 219292    39.0
# 219293    63.0
# 219294    16.0
# 219295    29.0
# 219296    20.0
# 219297    32.0
# 219298    57.0
# 219299    22.0
# 219300    49.0
# 219301    53.0
# 219302    64.0
# 219303    48.0
# 219304    34.0
# 219305    57.0
# 219306    44.0
# 219307    52.0
# 219308    48.0
# 219309    21.0
# 219310    57.0
# 219311    24.0
# 219312    21.0
# 219313    24.0
# 219314    31.0
# 219315    39.0
# ...

# %%
fixed_train_data = pd.DataFrame()

# %%
fixed_train_data['driver_age'] = train_data.driver_age

# %%
fixed_train_data
# Out:
#         driver_age
# 0             46.0
# 1             38.0
# 2             23.0
# 3             23.0
# 4             42.0
# 5             29.0
# 6             22.0
# 7             49.0
# 8             29.0
# 9             37.0
# 10            29.0
# 11            42.0
# 12            33.0
# 13            46.0
# 14            27.0
# 15            70.0
# 16            49.0
# 17            45.0
# 18            30.0
# 19            55.0
# 20            25.0
# 21            74.0
# 22            30.0
# 23            20.0
# 24            43.0
# 25            25.0
# 26            52.0
# 27            36.0
# 28            22.0
# 29            45.0
# ...            ...
# 219289        24.0
# 219290        22.0
# 219291        57.0
# 219292        39.0
# 219293        63.0
# 219294        16.0
# 219295        29.0
# 219296        20.0
# 219297        32.0
# 219298        57.0
# 219299        22.0
# 219300        49.0
# 219301        53.0
# 219302        64.0
# 219303        48.0
# ...
